# %% [markdown]
# # Data Pipeline

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np

# %%
tes = pd.read_excel('./data/TES/11657.xlsx', header=[18])

# %%
tes["Donor"] = pd.read_excel("./data/TES/11657.xlsx", usecols="B", header=None, names=["Donor"]).iloc[2]["Donor"]

# %%
tes["Stock Type"].value_counts()
# Out:
# PC    43
# FS    28
# OT    12
# LT    11
# HD     4
# SV     1
# IP     1
# Name: Stock Type, dtype: int64

# %%
types = {"PC": "Desktop", "LT": "Laptop"}

#for items in types.values():
    #for item in items:
        #if item not in tes["Stock Type"]:
            #tes["Type"] = 'Others'
        #else:
            #tes["Type"] = tes["Stock Type"].map(types)

tes['Type'] = tes['Stock Type'].map(types).fillna('Others')
            
tes.head()
# Out:
#       Book No. Manufacturer   Model     Processor Screen size Memory FDD  HDD  \
# 0  860051631-1           HP   2560P  i7-2640M 2.8        12.5   4096   -  500
# 1  860051631-2           HP   2540P  i7 L640 2.13        12.1   6144   -  160
# 2  860051631-3           HP   2560P  i5-2520M 2.5        12.5   4096   -  500
# 3  860051631-4           HP   2540P  i7 L640 2.13        12.1   6144   -  250
# 4  860051631-5           HP  820 G1            i5        12.5      -   -    -
#
#   CDROM Serial number    Asset Tag Stock Type  Weight (KG) Condition Code  \
# 0  NONE    CNU15009Q7  JIA-NB-S001         LT          2.0            A2G
# 1  NONE    CND129BCZD  JIA-NB-A009         LT          1.8            A2G
# 2  NONE    CNU1353GLZ  SUC-NB-S006         LT          2.0            A2G
# 3  NONE    CND1140HBT  JIA-NB-A001         LT          1.8            A2G
# 4  NONE    5CG5133RF3  JIA-NB-S008         LT          1.2            F2L
#
#          Stock Comments Disk Status Parent ID of HDD (XH)  Processing Fee  \
# 0                     -       WIPE                      -             8.0
# 1                     -       WIPE                      -             8.0
# 2                     -       WIPE                      -             8.0
# 3                     -       WIPE                      -             8.0
# 4  MISSING POWER SUPPLY           -                     -             8.0
#
#      Donor    Type
# 0  Donor 1  Laptop
# 1  Donor 1  Laptop
# 2  Donor 1  Laptop
# 3  Donor 1  Laptop
# 4  Donor 1  Laptop

# %%
tes.head()
# Out:
#       Book No. Manufacturer   Model     Processor Screen size Memory FDD  HDD  \
# 0  860051631-1           HP   2560P  i7-2640M 2.8        12.5   4096   -  500
# 1  860051631-2           HP   2540P  i7 L640 2.13        12.1   6144   -  160
# 2  860051631-3           HP   2560P  i5-2520M 2.5        12.5   4096   -  500
# 3  860051631-4           HP   2540P  i7 L640 2.13        12.1   6144   -  250
# 4  860051631-5           HP  820 G1            i5        12.5      -   -    -
#
#   CDROM Serial number    Asset Tag Stock Type  Weight (KG) Condition Code  \
# 0  NONE    CNU15009Q7  JIA-NB-S001         LT          2.0            A2G
# 1  NONE    CND129BCZD  JIA-NB-A009         LT          1.8            A2G
# 2  NONE    CNU1353GLZ  SUC-NB-S006         LT          2.0            A2G
# 3  NONE    CND1140HBT  JIA-NB-A001         LT          1.8            A2G
# 4  NONE    5CG5133RF3  JIA-NB-S008         LT          1.2            F2L
#
#          Stock Comments Disk Status Parent ID of HDD (XH)  Processing Fee  \
# 0                     -       WIPE                      -             8.0
# 1                     -       WIPE                      -             8.0
# 2                     -       WIPE                      -             8.0
# 3                     -       WIPE                      -             8.0
# 4  MISSING POWER SUPPLY           -                     -             8.0
#
#      Donor
# 0  Donor 1
# 1  Donor 1
# 2  Donor 1
# 3  Donor 1
# 4  Donor 1

# %%
lb = pd.read_excel("./data/CTG Circular/LB2200126_CTG - DONOR 7a_status.xls", header=[2])

# %%
lb["Product"].value_counts()
# Out:
# Monitor      554
# Printer       58
# PC            41
# Component      4
# Name: Product, dtype: int64

# %%
lb["Donor"] = pd.read_excel("./data/CTG Circular/LB2200031_CTG - DONOR 4_status.xls", usecols="F", header=None, names=["Donor"]).iloc[0]["Donor"]

# %%
ctg = pd.read_excel("./data/PlanBit/CTG - 0659 DONOR 8 ENGINERING REPORT.xlsx")

# %%
ctg["Product Type"].value_counts()
# Out:
# NOTEBOOK                   3020
# FLAT PANEL / MONITOR       1458
# DESKTOP                     244
# OTHER, VARIOUS PARTS         13
# COMPONENT                     9
# MOBILE PHONE                  1
# PRINTER (DESKTOP-MODEL)       1
# Name: Product Type, dtype: int64

# %%
ctg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Quantity            4746 non-null   int64
#  1   PATNumber           4746 non-null   object
#  2   Product Type        4746 non-null   object
#  3   Brand               4746 non-null   object
#  4   Model               4746 non-null   object
#  5   Serialnumber asset  4725 non-null   object
#  6   Client Asset Tag    2 non-null      object
#  7   Processor           3264 non-null   object
#  8   Memory              3258 non-null   object
#  9   Drive Size          3263 non-null   object
#  10  Drive Serial        4722 non-null   object
#  11  Erasure Status      3265 non-null   object
#  12  DISPLAY TYPES       4477 non-null   object
#  13  DISPLAY SIZES       4472 non-null   float64
#  14  KEYBOARD            4476 non-null   object
#  15  Battery Test        3265 non-null   object
#  16  GRADE-IN            4746 non-null   object
#  17  Defect 1            3225 non-null   object
#  18  Defect 2            3015 non-null   object
#  19  Defect 3            1638 non-null   object
#  20  Defect 4            645 non-null    object
#  21  Defect 5            996 non-null    object
#  22  Weight              4745 non-null   float64
# dtypes: float64(2), int64(1), object(20)
# memory usage: 852.9+ KB

# %%
donor_name = "./data/PlanBit/CTG - 0659 DONOR 8 ENGINERING REPORT.xlsx".split(" ")

# %%
donor_name
# Out:
# ['./data/PlanBit/CTG', '-', '0659', 'DONOR', '8', 'ENGINERING', 'REPORT.xlsx']

# %%
del(donor_name[0:3], donor_name[-2:])

# %%
donor_name
# Out:
# ['DONOR', '8']

# %%
new = lb["Specifications"].str.split(",", expand=True)

# %%
lb["RAM"] = new[1]

# %%
new = lb["Specifications"].str.split(",")[0][:2]
lb["Processor"] = str(new[0]) + "," + str(new[1])

lb["RAM"] = lb["Specifications"].str.split(",", expand=True)[2]
lb["HDD"] = lb["Specifications"].str.split(",", expand=True)[3]

# %%
lb["Processor"]
# Out:
# 0      CORE i5, 2.30GHZ
# 1      CORE i5, 2.30GHZ
# 2      CORE i5, 2.30GHZ
# 3      CORE i5, 2.30GHZ
# 4      CORE i5, 2.30GHZ
#              ...
# 514    CORE i5, 2.30GHZ
# 515    CORE i5, 2.30GHZ
# 516    CORE i5, 2.30GHZ
# 517    CORE i5, 2.30GHZ
# 518    CORE i5, 2.30GHZ
# Name: Processor, Length: 519, dtype: object

# %%
lb["Processor"]
# Out:
# 0      0,
# 1      0,
# 2      0,
# 3      0,
# 4      0,
#       ...
# 514    0,
# 515    0,
# 516    0,
# 517    0,
# 518    0,
# Name: Processor, Length: 519, dtype: object

# %%
pb = pd.read_excel("./data/PlanBit/CTG - 0616 DONOR 11 ENGINERING REPORT.xlsx")

# %%
ts = pd.read_excel("./data/TES/11657.xlsx", skiprows=18)

# %%
ctg = pd.read_excel("./data/CTG_Metabolic_ImpactCalculator_4 years use_4 years reuse.xlsx", engine='openpyxl')

# %%
a = lb.columns.values.tolist()

# %%
b = pb.columns.values.tolist()

# %%
c = ts.columns.values.tolist()

# %%
ctg.head(50)
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0          NaN  CIRCULAR ELECTRONICS ENVIRONMENTAL IMPACT CALC...
# 1          NaN                          VERSION 1: LIFE EXTENSION
# 2          NaN                                                NaN
# 3          NaN  These calculations are based on average impact...
# 4          NaN                                                NaN
# 5          NaN                                                NaN
# 6          NaN                                                NaN
# 7          NaN                                                NaN
# 8          NaN                                       INSTRUCTIONS
# 9          NaN                                             STEP 1
# 10         NaN                                             STEP 2
# 11         NaN                                             STEP 3
# 12         NaN                                             STEP 4
# 13         NaN                                               NOTE
# 14         NaN                                               LINK
# 15         NaN                                                NaN
# 16         NaN                                        INPUT TABLE
# 17         NaN                                         Asset type
# 18         NaN                                             Laptop
# 19         NaN                                            Desktop
# 20         NaN                                            Monitor
# 21         NaN                                              Other
# 22         NaN                                                NaN
# 23         NaN                                       OUTPUT TABLE
# 24         NaN                                    Impact category
# 25         NaN                                  Conflict minerals
# 26         NaN                              Electronic components
# 27         NaN                           Global warming potential
# 28         NaN                                    Toxic materials
# 29         NaN                                           Land use
# 30         NaN                                                NaN
# 31         NaN                        PER DEVICE IMPACT REDUCTION
# 32         NaN                                    Impact category
# 33         NaN                                  Conflict minerals
# 34         NaN                              Electronic components
# 35         NaN                           Global warming potential
# 36         NaN                                    Toxic materials
# 37         NaN                                           Land use
# 38         NaN                                                NaN
# 39         NaN                                                NaN
# 40         NaN            Amount of cars off the road per ton CO2
# 41         NaN              Amount of cars off the road for donor
#
#                                            Unnamed: 2  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   In column B of the Input Table, type the numbe...
# 10  In column C of the Input Table, type the refer...
# 11  In column D of the Input Table, type the exten...
# 12  The Output Table will populate with relative i...
# 13  Orange cells are the key inputs for the calcul...
# 14  If this spreadsheet doesn't operate as expecte...
# 15                                                NaN
# 16                                                NaN
# 17                                   Number of assets
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                   Reference impact
# 25                                                  0
# 26                                                  0
# 27                                                  0
# 28                                                  0
# 29                                                  0
# 30                                                NaN
# 31                                                NaN
# 32                                             Laptop
# 33                                           49.09562
# 34                                           1.930162
# 35                                                160
# 36                                          33.921868
# 37                                          10.419297
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
#
#                           Unnamed: 3                  Unnamed: 4   Unnamed: 5  \
# 0                                NaN                         NaN          NaN
# 1                                NaN                         NaN          NaN
# 2                                NaN                         NaN          NaN
# 3                                NaN                         NaN          NaN
# 4                                NaN                         NaN          NaN
# 5                                NaN                         NaN          NaN
# 6                                NaN                         NaN          NaN
# 7                                NaN                         NaN          NaN
# 8                                NaN                         NaN          NaN
# 9                                NaN                         NaN          NaN
# 10                               NaN                         NaN          NaN
# 11                               NaN                         NaN          NaN
# 12                               NaN                         NaN          NaN
# 13                               NaN                         NaN          NaN
# 14                               NaN                         NaN          NaN
# 15                               NaN                         NaN          NaN
# 16                               NaN                         NaN          NaN
# 17  Reference asset lifetime (years)  Lifetime extension (years)          NaN
# 18                                 4                           4          NaN
# 19                                 4                           4          NaN
# 20                                 4                           4          NaN
# 21                                 4                           4          NaN
# 22                               NaN                         NaN          NaN
# 23                               NaN                         NaN          NaN
# 24                Relative reduction                       Units          NaN
# 25                                 0                      tonnes          NaN
# 26                                 0                      tonnes          NaN
# 27                                 0       tonnes CO2 equivalent          NaN
# 28                                 0     tonnes 2,4DC equivalent          NaN
# 29                                 0                    hectares          NaN
# 30                               NaN                         NaN          NaN
# 31                               NaN                         NaN          NaN
# 32                           Desktop                     Monitor        Other
# 33                           17.4156                     9.35479     25.28867
# 34                         13.237774                    1.244765      3.35149
# 35                               400                         350          450
# 36                         19.903035                   18.758799  1053.295856
# 37                          5.599258                   10.639266     8.577784
# 38                               NaN                         NaN          NaN
# 39                               NaN                         NaN          NaN
# 40                          0.214286                         NaN          NaN
# 41                                 0                         NaN          NaN
#
#                            Unnamed: 6  Unnamed: 7  Unnamed: 8
# 0                                 NaN         NaN         NaN
# 1                                 NaN         NaN         NaN
# 2                                 NaN         NaN         NaN
# 3                                 NaN         NaN         NaN
# 4                                 NaN         NaN         NaN
# 5                                 NaN         NaN         NaN
# 6                                 NaN         NaN         NaN
# 7                                 NaN         NaN         NaN
# 8                                 NaN         NaN         NaN
# 9                                 NaN         NaN         NaN
# 10                                NaN         NaN         NaN
# 11                                NaN         NaN         NaN
# 12                                NaN         NaN         NaN
# 13                                NaN         NaN         NaN
# 14                                NaN         NaN         NaN
# 15                                NaN         NaN         NaN
# 16  Number of assets recovered by CTG         NaN         NaN
# 17                               2020      2018.0      2017.0
# 18                              25782     24951.0     29169.0
# 19                              23386     29154.0     24780.0
# 20                              15649     35916.0     29951.0
# 21                              27738     21196.0     28153.0
# 22                                NaN         NaN         NaN
# 23                                NaN         NaN         NaN
# 24                                NaN         NaN         NaN
# 25                                NaN         NaN         NaN
# 26                                NaN         NaN         NaN
# 27                                NaN         NaN         NaN
# 28                                NaN         NaN         NaN
# 29                                NaN         NaN         NaN
# 30                                NaN         NaN         NaN
# 31                                NaN         NaN         NaN
# 32                              Units         NaN         NaN
# 33                              grams         NaN         NaN
# 34                          kilograms         NaN         NaN
# 35           kilograms CO2 equivalent         NaN         NaN
# 36             grams 2,4DC equivalent         NaN         NaN
# 37                                m2a         NaN         NaN
# 38                                NaN         NaN         NaN
# 39                                NaN         NaN         NaN
# 40                                NaN         NaN         NaN
# 41                                NaN         NaN         NaN

# %%
all_cols = a + b + c

# %%
print(all_cols)
# Out:
# ['Load no.', 'Tracking reference', 'Serial no.', 'Asset Tag', 'Qty', 'Product', 'Brand', 'Model', 'Specifications', 'Defects', 'Grade', 'Quantity', 'PATNumber', 'Product Type', 'Brand', 'Model', 'Serialnumber asset', 'Client Asset Tag', 'Processor', 'Memory', 'Drive Size', 'Drive Serial', 'Erasure Status', 'DISPLAY TYPES', 'DISPLAY SIZES', 'KEYBOARD', 'Battery Test', 'GRADE-IN', 'Defect 1', 'Defect 2', 'Defect 3', 'Defect 4', 'Defect 5', 'Weight', 'Book No.', 'Manufacturer', 'Model', 'Processor', 'Screen size', 'Memory', 'FDD', 'HDD', 'CDROM', 'Serial number', 'Asset Tag', 'Stock Type', 'Weight (KG)', 'Condition Code', 'Stock Comments', 'Disk Status', 'Parent ID of HDD (XH)', 'Processing Fee']

# %%
all_cols = set(all_cols)

# %%
print(all_cols)
print("Number of unique columns:", len(all_cols))
# Out:
# {'Weight (KG)', 'Memory', 'Serialnumber asset', 'Parent ID of HDD (XH)', 'KEYBOARD', 'FDD', 'Quantity', 'Processing Fee', 'Drive Serial', 'CDROM', 'Manufacturer', 'PATNumber', 'Asset Tag', 'Client Asset Tag', 'Serial number', 'Defect 4', 'Disk Status', 'Grade', 'Book No.', 'Defect 2', 'Tracking reference', 'Drive Size', 'Defects', 'Stock Comments', 'Weight', 'Defect 1', 'Product', 'Screen size', 'Model', 'GRADE-IN', 'Load no.', 'Serial no.', 'Erasure Status', 'DISPLAY SIZES', 'Stock Type', 'Qty', 'Specifications', 'DISPLAY TYPES', 'Defect 3', 'Processor', 'Product Type', 'HDD', 'Battery Test', 'Defect 5', 'Brand', 'Condition Code'}
# Number of unique columns: 46

# %%
devices = pd.DataFrame({"Quantity", "Reference", "Serial Number", "Asset Tag", "Type", "Brand", "Model", "Processor", "RAM", "HDD", "Display", "Weight", "Defects", "Grade", "Disk Status"})

# %%
devices
# Out:
# Empty DataFrame
# Columns: [Disk Status, Processor, Serial Number, Reference, HDD, Type, Quantity, Model, RAM, Grade, Display, Defects, Brand, Asset Tag, Weight]
# Index: []

# %%
new_index = ["Quantity", "Reference", "Serial Number", "Asset Tag", "Type", "Brand", "Model", "Processor", "RAM", "HDD", "Display", "Weight", "Defects", "Grade", "Disk Status"]

# %%
devices.reindex(columns=new_index)
# Out:
# Empty DataFrame
# Columns: [Quantity, Reference, Serial Number, Asset Tag, Type, Brand, Model, Processor, RAM, HDD, Display, Weight, Defects, Grade, Disk Status]
# Index: []

# %%
def df_formating(path, donor=None):
    
    index = {"Quantity": ["Qty", "Quantity"], 
             "Reference": ["Book No.", "PATNumber", "Reference"], 
             "Serial Number": ["Serial no.", "Serial number", "Serialnumber asset"], 
             "Asset Tag": ["Asset Tag", "Client Asset Tag"], 
             "Type": ["Product type", "Product"], 
             "Brand": ["Brand", "Manufacturer"], 
             "Model": ["Model"], 
             "Processor": ["Processor"], 
             "RAM": ["Memory", "RAM"], 
             "HDD": ["Drive Size", "HDD"], 
             "Display": ["DISPLAY SIZES", "Screen size"], 
             "Weight": ["Weight (KG)", "Weight"], 
             "Grade": ["Grade", "Condition Code", "GRADE-IN"], 
             "Defects": ["Defects", "Stock Comments"],
             "Disk Status": ["Disk Status", "Erasure Status"],
             "Donor": ["Donor"]
            }
    
    excel_file = path.split("/")

    if excel_file[-1][:2] == "LB":
        df = pd.read_excel(path, header=[2])
        new = df["Specifications"].str.split(",", expand=True)[0][:2]
        df["Processor"] = str(new[0]) + "," + str(new[1])
        df["RAM"] = df["Specifications"].str.split(",", expand=True)[2]
        df["HDD"] = df["Specifications"].str.split(",", expand=True)[3]
        df["Reference"] = df["Load no."].astype(str) + " - " + df["Tracking reference"].astype(str)
        
        if donor is None:
            try:
                df["Donor"] = donor            
            except:       
                df["Donor"] = pd.read_excel(path, usecols="F", header=None, names=["Donor"]).iloc[0]["Donor"]        
        
        
    elif excel_file[-1][:2] == "CT":
        df = pd.read_excel(path)
        df["Defects"] = df["Defect 1"] + "," + df["Defect 2"] + "," + df["Defect 3"] + "," + df["Defect 4"] + "," + df["Defect 5"]
        donor_name = path.split(" ")
        del(donor_name[:3], donor_name[-2:])
        df["Donor"] = " ".join(donor_name)
        
        if donor:
            try:
                df["Donor"] = donor            
            except:       
                df["Donor"] = pd.read_excel(path, usecols="F", header=None, names=["Donor"]).iloc[0]["Donor"]
                 
    else:
        df = pd.read_excel(path, header=[18])
        df["Donor"] = pd.read_excel(path, usecols="B", header=None, names=["Donor"]).iloc[2]["Donor"]
    
    columns = list(df)
    new_df = pd.DataFrame(columns=index)
    print(list(new_df))
    
    print(df.head())
    
    for k, v in index.items():
        print("k", k)
        print("v", v)
        for i in v:
            try:
                new_df[k] = df[i]
            except:
                continue             
                
    new_df["Quantity"] = new_df["Quantity"].fillna(1)
    new_df["Type"] = new_df["Type"].fillna("PC")
            
        
    return new_df

# %%
def donor_column(donor=None):
    try:
        df["Donor"] = donor            
    except:       
        df["Donor"] = pd.read_excel(path, usecols="F", header=None, names=["Donor"]).iloc[0]["Donor"]

# %%
dff = df_formating("./data/PlanBit/CTG - 0659 DONOR 8 ENGINERING REPORT.xlsx", "Tony")
# Out:
# ['Quantity', 'Reference', 'Serial Number', 'Asset Tag', 'Type', 'Brand', 'Model', 'Processor', 'RAM', 'HDD', 'Display', 'Weight', 'Grade', 'Defects', 'Disk Status', 'Donor']
#    Quantity     PATNumber Product Type Brand          Model  \
# 0         1  P22506590102      DESKTOP  DELL  OPTIPLEX 7010
# 1         1  P22506590103      DESKTOP  DELL  OPTIPLEX 7010
# 2         1  P22506590104      DESKTOP  DELL  OPTIPLEX 7010
# 3         1  P22506590105      DESKTOP  DELL  OPTIPLEX 7010
# 4         1  P22506590106      DESKTOP  DELL  OPTIPLEX 7010
#
#   Serialnumber asset Client Asset Tag                 Processor Memory  \
# 0            6PXFGZ1              NaN  Core(TM) i5-3570 3.40GHz    4GB
# 1            HL20H5J              NaN  Core(TM) i5-3570 3.40GHz    4GB
# 2            2pzgwx1              NaN  Core(TM) i5-3570 3.40GHz    4GB
# 3            2PZGWX1              NaN  Core(TM) i5-3570 3.40GHz    4GB
# 4            CBX3J5J              NaN  Core(TM) i5-3570 3.40GHz    4GB
#
#   Drive Size  ...   Battery Test GRADE-IN Defect 1  Defect 2 Defect 3  \
# 0      128GB  ...  not performed       A3      NaN       NaN      NaN
# 1      128GB  ...  not performed       A3      NaN       NaN      NaN
# 2      128GB  ...  not performed       A3      NaN       NaN      NaN
# 3      128GB  ...  not performed       A3      NaN       NaN      NaN
# 4      128GB  ...  not performed       A3      NaN       NaN      NaN
#
#   Defect 4 Defect 5 Weight Defects Donor
# 0      NaN      NaN    6.0     NaN  Tony
# 1      NaN      NaN    6.0     NaN  Tony
# 2      NaN      NaN    6.0     NaN  Tony
# 3      NaN      NaN    6.0     NaN  Tony
# 4      NaN      NaN    6.0     NaN  Tony
#
# [5 rows x 25 columns]
# k Quantity
# v ['Qty', 'Quantity']
# k Reference
# v ['Book No.', 'PATNumber', 'Reference']
# k Serial Number
# v ['Serial no.', 'Serial number', 'Serialnumber asset']
# k Asset Tag
# v ['Asset Tag', 'Client Asset Tag']
# k Type
# v ['Product type', 'Product']
# k Brand
# v ['Brand', 'Manufacturer']
# k Model
# v ['Model']
# k Processor
# v ['Processor']
# k RAM
# v ['Memory', 'RAM']
# k HDD
# v ['Drive Size', 'HDD']
# k Display
# v ['DISPLAY SIZES', 'Screen size']
# k Weight
# v ['Weight (KG)', 'Weight']
# k Grade
# v ['Grade', 'Condition Code', 'GRADE-IN']
# k Defects
# v ['Defects', 'Stock Comments']
# k Disk Status
# v ['Disk Status', 'Erasure Status']
# k Donor
# v ['Donor']

# %%
dff.isna().sum()
# Out:
# Quantity           0
# Reference          0
# Serial Number      0
# Asset Tag        501
# Type               0
# Brand              0
# Model              0
# Processor          0
# RAM                8
# HDD               21
# Display          519
# Weight           519
# Grade              0
# Defects            6
# Disk Status      519
# Donor              0
# dtype: int64

# %%
dff.head()
# Out:
#    Quantity     Reference Serial Number Asset Tag Type Brand          Model  \
# 0         1  P22506590102       6PXFGZ1       NaN   PC  DELL  OPTIPLEX 7010
# 1         1  P22506590103       HL20H5J       NaN   PC  DELL  OPTIPLEX 7010
# 2         1  P22506590104       2pzgwx1       NaN   PC  DELL  OPTIPLEX 7010
# 3         1  P22506590105       2PZGWX1       NaN   PC  DELL  OPTIPLEX 7010
# 4         1  P22506590106       CBX3J5J       NaN   PC  DELL  OPTIPLEX 7010
#
#                   Processor  RAM    HDD  Display  Weight Grade Defects  \
# 0  Core(TM) i5-3570 3.40GHz  4GB  128GB      NaN     6.0    A3     NaN
# 1  Core(TM) i5-3570 3.40GHz  4GB  128GB      NaN     6.0    A3     NaN
# 2  Core(TM) i5-3570 3.40GHz  4GB  128GB      NaN     6.0    A3     NaN
# 3  Core(TM) i5-3570 3.40GHz  4GB  128GB      NaN     6.0    A3     NaN
# 4  Core(TM) i5-3570 3.40GHz  4GB  128GB      NaN     6.0    A3     NaN
#
#   Disk Status Donor
# 0  Successful  Tony
# 1  Successful  Tony
# 2  Successful  Tony
# 3  Successful  Tony
# 4  Successful  Tony

# %%
dff[dff['Donor'].isna()]
# Out:
# Empty DataFrame
# Columns: [Quantity, Reference, Serial Number, Asset Tag, Type, Brand, Model, Processor, RAM, HDD, Display, Weight, Grade, Defects, Disk Status, Donor]
# Index: []

# %% [markdown]
# ---

# %%
class Df_formating():
    
    
    def __init__(self, path, donor=None):
        
        # self.df = pd.DataFrame()
        self.final_df: pd.DataFrame = None
        self.path: str = path
        self.donor: str = donor
        self.excel_file = path.split("/")
        self.index: dict = {"Quantity": ["Qty", "Quantity"], 
             "Reference": ["Book No.", "PATNumber", "Reference"], 
             "Serial Number": ["Serial no.", "Serial number", "Serialnumber asset"], 
             "Asset Tag": ["Asset Tag", "Client Asset Tag"], 
             "Type": ["Product type", "Product", "Stock Type"], 
             "Brand": ["Brand", "Manufacturer"], 
             "Model": ["Model"], 
             "Processor": ["Processor"], 
             "RAM": ["Memory", "RAM"], 
             "HDD": ["Drive Size", "HDD"], 
             "Display": ["DISPLAY SIZES", "Screen size"], 
             "Weight": ["Weight (KG)", "Weight"], 
             "Grade": ["Grade", "Condition Code", "GRADE-IN"], 
             "Defects": ["Defects", "Stock Comments"],
             "Disk Status": ["Disk Status", "Erasure Status"],
             "Donor": ["Donor"]
            }        
        self.types = {
            "LT": "Laptop", "NOTEBOOK": "Laptop", "Notebook": "laptop", "Desktop": "Desktop", 
            "DESKTOP": "Desktop", "PC": "Desktop", "CS": "Monitor", "MS": "Monitor", "LD": "Monitor", 
            "FS": "Monitor", "FLAT PANEL / MONITOR": "Monitor", "Monitor": "Monitor"}
        
        if self.excel_file[-1][:2] == "LB":
            self.lb_parsing()
        elif self.excel_file[-1][:2] == "CT":
            self.ct_parsing()
        else:
            self.tes_parsing()
            
        
    def lb_parsing(self):
        
        df = pd.read_excel(self.path, header=[2])
        new = df["Specifications"].str.split(",", expand=True)[0][:2]
        df["Processor"] = str(new[0]) + "," + str(new[1])
        df["RAM"] = df["Specifications"].str.split(",", expand=True)[2]
        df["HDD"] = df["Specifications"].str.split(",", expand=True)[3]
        df["Reference"] = df["Load no."].astype(str) + " - " + df["Tracking reference"].astype(str)
        self.final_df = df
        self.create_df()
        
         
    def ct_parsing(self):
        
        df = pd.read_excel(self.path)
        df["Defects"] = df["Defect 1"] + "," + df["Defect 2"] + "," + df["Defect 3"] + "," + df["Defect 4"] + "," + df["Defect 5"]
        donor_name = self.path.split(" ")
        del(donor_name[:3], donor_name[-2:])
        df["Donor"] = " ".join(donor_name)
        self.final_df = df
        self.create_df()
        
        
    def tes_parsing(self):
        
        
        df = pd.read_excel(self.path, header=[18])
        df["Donor"] = pd.read_excel(self.path, usecols="B", header=None, names=["Donor"]).iloc[2]["Donor"]
        self.final_df = df
        self.create_df()
    
        
    def create_df(self):
        
        df = self.final_df
        new_df = pd.DataFrame(columns=self.index)
        for k, v in self.index.items():
            for i in v:
                try:
                    new_df[k] = df[i]
                except:
                    continue
                    
        if self.donor != None:
            new_df["Donor"] = self.donor
            
        new_df = new_df.replace("-", np.nan)
        self.final_df = new_df
        self.co2_type_converter()
        
    
    def co2_type_converter(self):    
        
        df = self.final_df
        df['Type_calc'] = df["Type"].map(self.types).fillna('Others')  
        self.final_df = df
        
        return self.final_df

# %%
frame = Df_formating("./data/CTG Circular/LB2200126_CTG - DONOR 7a_status.xls")

# %%
frame.final_df.head()
# Out:
#    Quantity               Reference Serial Number       Asset Tag       Type  \
# 0         1  LB2200126 - C22B019419       APC4847  115-1001255-31  Component
# 1         1  LB2200126 - C22B019420       AOG7476  115-0066442-07  Component
# 2         1  LB2200126 - C22B019421       APC5039  115-1001770-61  Component
# 3         1  LB2200126 - C22B019422       APC2594  115-1001632-20  Component
# 4         1  LB2200126 - C22B019679    3CQ050PGRF  115-0007023-49    Monitor
#
#             Brand            Model Processor  RAM  HDD Display Weight Grade  \
# 0  ATOS WORLDLINE           YOMANI   nan,nan  NaN  NaN     NaN    NaN     T
# 1  ATOS WORLDLINE           YOMANI   nan,nan  NaN  NaN     NaN    NaN     T
# 2  ATOS WORLDLINE           YOMANI   nan,nan  NaN  NaN     NaN    NaN     T
# 3  ATOS WORLDLINE           YOMANI   nan,nan  NaN  NaN     NaN    NaN     T
# 4              HP  COMPAQ LA2205WG   nan,nan  NaN  NaN     NaN    NaN    C+
#
#        Defects Disk Status Donor Type_calc
# 0          NaN         NaN   NaN    Others
# 1          NaN         NaN   NaN    Others
# 2          NaN         NaN   NaN    Others
# 3          NaN         NaN   NaN    Others
# 4  LCD stained         NaN   NaN   Monitor

# %%
frame.final_df["Type_calc"].value_counts()
# Out:
# Monitor    554
# Others      62
# Desktop     41
# Name: Type_calc, dtype: int64
